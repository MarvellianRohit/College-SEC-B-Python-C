# %%
print("hello ")
# Out:
# hello

# %%
A = input("enter the value:")
print(A)
# Out:
# enter the value:10
# 10

# %%
A= 10
B= 20
C= A+B

# %%
print(C)
# Out:
# 30

# %%
A= int(input("enter the number "))
B=int(input("enter the number "))

C=A+B
print(C)
# Out:
# enter the number 20
# enter the number 29
# 49

# %%
A="hello "
B ="wrold"

C = A+B
print(C)
print(C[::-1])
print(C[2:5])
print(C[1:10])
print(C.upper())
D="                   hello wrold";print(D);print(D.strip());

E= C[1:5]+" "+C[7:10]
print(E)
F= C.replace("he","J")
print(F)
# Out:
# hello wrold
# dlorw olleh
# llo
# ello wrol
# HELLO WROLD
#                    hello wrold
# hello wrold
# ello rol
# Jllo wrold

# %%
A=20;B=2.5

C=print(A+B)
# Out:
# 22.5

# %%
print("hello");print("wrold")
# Out:
# hello
# wrold

# %% [markdown]
# #String

# %%
txt = "hello ,and wellcome to class,hello ,hello "
x= txt.count("class")
if x>0:
  print("the word is present into the string")
else:
  print("............")
print(x)
# Out:
# the word is present into the string
# 1

# %%
text = "Hello, World!"
length = len(text)
print(length)
# Out:
# 13

# %%
txt = "hello ,and wellcome to class,hello ,hello "
x=txt.title()
print(x)
y=txt.find("and")
print(y)
# Out:
# Hello ,And Wellcome To Class,Hello ,Hello
# 7
